# %% [markdown]
# # 🧪 Exploratory Data Analysis (EDA)
# Notebook ini digunakan untuk menuliskan proses EDA (analisis deskriptif dan visualisasi data).
# - Gunakan `pandas` dan `matplotlib/seaborn`
# - Tampilkan statistik deskriptif
# - Visualisasi distribusi, korelasi, outlier, dll.

# %%
# Sel 1: Import library dan muat data
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# Menambahkan folder root ke path agar bisa import dari src
# Ini memungkinkan notebook untuk menemukan modul di folder 'src'
sys.path.append(os.path.abspath(os.path.join('..')))
from src import config

# Memuat data mentah menggunakan path dari config
df = pd.read_csv(config.RAW_DATA_PATH)

print("Data berhasil dimuat. Jumlah baris:", len(df))
df.head()
# Out:
# Data berhasil dimuat. Jumlah baris: 106674
#                                   commit_id        project  buggy    fix  \
# 0  7b8480744ea6e6fb41efd4329bb470c8f3c763db  apache/groovy  False  False
# 1  192b631e7be302ecde822546ba70a9853ddbda01  apache/groovy  False  False
# 2  0ab6465a7dece117c61c3efd3ec95d20524bdad6  apache/groovy  False  False
# 3  449241d5fa1aeadd5eb9fa1280d4104dc0dfb891  apache/groovy  False  False
# 4  698df9f5b0816e05bbf97a390428f8ef94e0cdbf  apache/groovy  False  False
#
#    year  author_date   la  ld  nf  nd  ns       ent      ndev       age  \
# 0  2003   1070355653  372  23   8   3   3  2.669743  0.250000  3.625000
# 1  2003   1063298262    2   2   2   2   1  1.000000  1.000000  0.000000
# 2  2003   1069704572   41  26   3   3   2  1.237612  0.666667  5.333333
# 3  2003   1068487625    8   6   2   1   1  0.591673  1.000000  3.000000
# 4  2003   1063313516   70   4   6   3   1  2.519672  0.333333  0.000000
#
#       nuc  aexp  arexp      asexp
# ...

# %%
# Sel 2: Informasi dasar dan statistik deskriptif
# --- Gunakan sel Markdown di atas ini dengan judul: "1. Tinjauan Umum Data" ---
print("Informasi Dataset:")
df.info()

print("\nStatistik Deskriptif untuk Kolom Numerik:")
df.describe().T
# Out:
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106674 entries, 0 to 106673
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   commit_id    106674 non-null  object
#  1   project      106674 non-null  object
#  2   buggy        106674 non-null  bool
#  3   fix          106674 non-null  bool
#  4   year         106674 non-null  int64
#  5   author_date  106674 non-null  int64
#  6   la           106674 non-null  int64
#  7   ld           106674 non-null  int64
#  8   nf           106674 non-null  int64
#  9   nd           106674 non-null  int64
#  10  ns           106674 non-null  int64
#  11  ent          106674 non-null  float64
#  12  ndev         106674 non-null  float64
#  13  age          106674 non-null  float64
#  14  nuc          106674 non-null  float64
#  15  aexp         106674 non-null  int64
#  16  arexp        106674 non-null  float64
# ...

# %%
# Sel 3: Pengecekan nilai kosong (missing values)
# --- Gunakan sel Markdown di atas ini dengan judul: "2. Analisis Nilai Kosong" ---
print("Jumlah nilai kosong per kolom:")
df.isnull().sum()
# Out:
# Jumlah nilai kosong per kolom:
# commit_id      0
# project        0
# buggy          0
# fix            0
# year           0
# author_date    0
# la             0
# ld             0
# nf             0
# nd             0
# ns             0
# ent            0
# ndev           0
# age            0
# nuc            0
# aexp           0
# arexp          0
# asexp          0
# dtype: int64

# %%
# Sel 4: Visualisasi Distribusi Fitur
# --- Gunakan sel Markdown di atas ini dengan judul: "3. Visualisasi Distribusi Fitur" ---

# Fitur yang sudah ada di data mentah
raw_features_for_eda = ['la', 'ld', 'nf', 'ent', 'nd', 'ns', 'aexp', 'arexp', 'asexp']

df[raw_features_for_eda].hist(bins=30, figsize=(15, 10), layout=(3, 3))
plt.suptitle("Histogram Distribusi Fitur Numerik (Data Mentah)", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Sel 5: Visualisasi Heatmap Korelasi
# --- Gunakan sel Markdown di atas ini dengan judul: "4. Analisis Korelasi" ---
plt.figure(figsize=(12, 10))

# Kita hanya gunakan fitur yang sudah ada di data mentah untuk korelasi
correlation_data = df[raw_features_for_eda].copy()
correlation_data['buggy'] = df['buggy'].astype(int) # Tambahkan target untuk melihat korelasinya

sns.heatmap(correlation_data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title("Heatmap Korelasi Antar Fitur dan Target", fontsize=16)
plt.show()
